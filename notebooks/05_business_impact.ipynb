# %%
import pandas as pd

df = pd.read_csv("../data/telco_featured.csv")

df.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... StreamingTV  \
# 0  No phone service             DSL             No  ...          No
# 1                No             DSL            Yes  ...          No
# 2                No             DSL            Yes  ...          No
# 3  No phone service             DSL            Yes  ...          No
# 4                No     Fiber optic             No  ...          No
#
#   StreamingMovies        Contract PaperlessBilling              PaymentMethod  \
# ...

# %%
total_customers = len(df)

print("Total Customers:", total_customers)
# Out:
# Total Customers: 7043

# %%
churned_customers = len(df[df["Churn"] == "Yes"])

print("Churned Customers:", churned_customers)
# Out:
# Churned Customers: 1869

# %%
churn_rate = (
    churned_customers / total_customers
) * 100

print("Churn Rate: {:.2f}%".format(churn_rate))
# Out:
# Churn Rate: 26.54%

# %%
churned = df[df["Churn"] == "Yes"]

revenue_loss = churned["MonthlyCharges"].sum()

print("Revenue Loss:", revenue_loss)
# Out:
# Revenue Loss: 139130.85

# %%
contract_churn = pd.crosstab(
    df["Contract"],
    df["Churn"]
)

contract_churn
# Out:
# Churn             No   Yes
# Contract
# Month-to-month  2220  1655
# One year        1307   166
# Two year        1647    48

# %%
pd.crosstab(
    df["tenure_group"],
    df["Churn"]
)
# Out:
# Churn           No   Yes
# tenure_group
# 0-1 year      1138  1037
# 1-2 years      730   294
# 2-4 years     1269   325
# 4-6 years     2026   213

# %% [markdown]
# 1. Focus on retaining month-to-month customers.
#
# 2. Encourage customers to switch to long-term contracts.
#
# 3. Provide discounts for new customers during first year.
#
# 4. Target high-value customers before they churn.
#
# 5. Improve customer support and engagement.

# %%
import os

print("DATA FILES:")
print(os.listdir("../data"))

print("\nREPORT FILES:")
print(os.listdir("../reports"))

print("\nSRC FILES:")
print(os.listdir("../src"))
# Out:
# DATA FILES:
# ['.ipynb_checkpoints', 'telco_cleaned.csv', 'telco_featured.csv', 'telco_raw.csv']
#
# REPORT FILES:
# ['churn_distribution.png', 'contract_vs_churn.png', 'correlation_heatmap.png', 'tenure_vs_churn.png']
#
# SRC FILES:
# ['.ipynb_checkpoints', 'business_impact.py', 'data_cleaner.py', 'data_loader.py', 'eda_plots.py', 'feature_engineer.py', '__init__.py']
